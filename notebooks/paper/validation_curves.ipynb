# %%
# %load_ext autoreload
# %autoreload

from retro_branching.utils import get_most_recent_checkpoint_foldername, PlotAesthetics

import glob
import gzip
import pickle
from collections import defaultdict
import copy
import numpy as np
import scipy.stats as st
import math
from ordered_set import OrderedSet
import time
from sqlitedict import SqliteDict
import os

import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
pd.set_option("display.max_rows", 100, "display.max_columns", None)
from tabulate import tabulate
from IPython.display import display

# %%
# # 500x1000 Etheve et al. baseline
# agent_to_path = {
#                  'PB': '/scratch/datasets/retro_branching/instances/set_covering_n_rows_500_n_cols_1000/scip_gasse_2019/baselines/pseudocost/rl_validator/rl_validator_1/',
#                  'SB': '/scratch/datasets/retro_branching/instances/set_covering_n_rows_500_n_cols_1000/scip_gasse_2019/baselines/strong_branching/rl_validator/rl_validator_1/',
#                  'IL': '/scratch/datasets/retro_branching/instances/set_covering_n_rows_500_n_cols_1000/scip_gasse_2019/baselines/gnn_361_checkpoint_139/rl_validator/rl_validator_1/',
# #                  'Step-Orig': <path>,
# #                  'Etheve': '/scratch/datasets/retro_branching/instances/set_covering_n_rows_500_n_cols_1000/scip_gasse_2019/baselines/dqn_gnn_1484_checkpoint_79/rl_validator/rl_validator_1/',
#                  'Step-Retro': '/scratch/datasets/retro_branching/instances/set_covering_n_rows_500_n_cols_1000/scip_gasse_2019/baselines/dqn_gnn_1481_checkpoint_79/rl_validator/rl_validator_1/',
# #                  'MAB-Retro': <path>,
#                 }

# # 500x1000 set covering baseline comparison
# agent_to_path = {
# #                  'PB': '/scratch/datasets/retro_branching/instances/set_covering_n_rows_500_n_cols_1000/scip_gasse_2019/baselines/pseudocost/rl_validator/rl_validator_1/',
# #                  'SB': '/scratch/datasets/retro_branching/instances/set_covering_n_rows_500_n_cols_1000/scip_gasse_2019/baselines/strong_branching/rl_validator/rl_validator_1/',
# #                  'IL': '/scratch/datasets/retro_branching/instances/set_covering_n_rows_500_n_cols_1000/scip_gasse_2019/baselines/gnn_361_checkpoint_139/rl_validator/rl_validator_1/',
#                  'Retro': '/scratch/datasets/retro_branching/dqn_learner/dqn_gnn/dqn_gnn_1481/',
#                  'Original': '/scratch/datasets/retro_branching/dqn_learner/dqn_gnn/dqn_gnn_1405/',
#                  'FMSTS': '/scratch/datasets/retro_branching/dqn_learner/dqn_gnn/dqn_gnn_1484/',
# #                  'MAB-Retro': '/scratch/datasets/retro_branching/dqn_learner/dqn_gnn/dqn_gnn_1485/',
# #                  'NLPG-Retro': '/scratch/datasets/retro_branching/dqn_learner/dqn_gnn/dqn_gnn_1487/',
#                 }

# # 500x1000 different sub-tree construction heuristics
# agent_to_path = {
#                  'MLPG': '/scratch/datasets/retro_branching/dqn_learner/dqn_gnn/dqn_gnn_1481/',
#                  'R': '/scratch/datasets/retro_branching/dqn_learner/dqn_gnn/dqn_gnn_1488/',
#                  'VO': '/scratch/datasets/retro_branching/dqn_learner/dqn_gnn/dqn_gnn_1489/',
#                  'D': '/scratch/datasets/retro_branching/dqn_learner/dqn_gnn/dqn_gnn_1490/',
#                 }

# # 500x1000 set covering
agent_to_path = {
                 #'Retro': '/scratch/datasets/retro_branching/dqn_learner/dqn_gnn/dqn_gnn_1481/'
                 'il_10':'/data/ltf/code/retro_branching_offline/outputs/scratch_models/il_10/gnn/gnn_0/',
                 'il_10_cl_10': '/data/ltf/code/retro_branching_offline/outputs/downsteam_models/il_10_cl_10/gnn/gnn_0/',
                 'il_10_cl_100': '/data/ltf/code/retro_branching_offline/outputs/downsteam_models/il_10_cl_100/gnn/gnn_0/',
                 'il_10_cl_100_checkpoint2': '/data/ltf/code/retro_branching_offline/outputs/downsteam_models/il_10_cl_100_checkpoint2/gnn/gnn_0/'
                }

# # # 165x230 set covering
# agent_to_path = {
#                  'Retro': '/scratch/datasets/retro_branching/dqn_learner/dqn_gnn/dqn_gnn_1491/'
#                 }


metrics = ['num_nodes', 'lp_iterations']
metric_to_label = {'num_nodes': 'Nodes', 'lp_iterations': 'LP Iterations'}

# %%
# load agent logs
episodes_logs_dict, epochs_logs_dict = {}, {}
validation_dict = defaultdict(list)
agent_name_to_display_name = {}
for display_name, agent_path in agent_to_path.items():
    if agent_path[-1] != '/':
        raise Exception(f'Agent path {agent_path} must end with /')
    orig_agent_name = agent_path.split('/')[-4]
    print(f'\nLoading logs for {display_name} agent from {agent_path}...')
    
    # load epochs log
    start_t = time.time()
    # epochs_logs_dict[display_name] = {}
    # start_t = time.time()
    # with SqliteDict(agent_path+'/database/epochs_log.sqlite') as log:
    #     for key, val in log.items():
    #         # read into memory
    #         epochs_logs_dict[display_name][key] = val
    #     log.close()
    # print(f'Loaded epoch data in {time.time() - start_t:.3f} s.')
    
    # # get total epochs ran for this agent
    # total_epochs = epochs_logs_dict[display_name]['num_epochs'][-1]
    total_epochs = 100
    # get paths to saved agent checkpoints
    checkpoint_paths = sorted(glob.glob(agent_path+'/checkpoint_*'))
    checkpoints = [int(path.split('/')[-1].split('_')[-1]) for path in checkpoint_paths]
    
    # calc checkpoint frequency (-1 to account for checkpoint saved at epoch 0)
    checkpoint_freq = int(total_epochs / (len(checkpoints) - 1))
    print(f'Number of epochs: {total_epochs} | Number of checkpoints: {len(checkpoints)} | Checkpoint frequency: {checkpoint_freq}')
    
    # load validation data at each checkpoint
    for checkpoint in sorted(checkpoints):
        checkpoint_path = agent_path + f'/checkpoint_{checkpoint}'
        validator_path = checkpoint_path + '/rl_validator/rl_validator_1/'
        if os.path.isdir(validator_path):
            print(f'{display_name} {checkpoint_path.split("/")[-1]} has validator data, loading...')
            start_t = time.time()
            
            cp = get_most_recent_checkpoint_foldername(validator_path, idx=-1)
            validator_path += f'{cp}/'
            with gzip.open(*glob.glob(validator_path+'*log.pkl'), 'rb') as f:
                validation_log = pickle.load(f)

            for metric in metrics:
                # metrics are stored as per episode step reward, so total metric is sum of reward at each step
                validation_dict[metric] += [abs(np.sum(rewards)) for rewards in validation_log[orig_agent_name][metric]]
            for _ in range(len(validation_log[orig_agent_name][metric])):
                # add agent name and epoch for each episode
                validation_dict['Agent'].append(display_name)
                validation_dict['num_epochs'].append(int((checkpoint-1)*checkpoint_freq))
                validation_dict['Checkpoints'].append(checkpoint)
            
            print(f'Loaded validator data in {time.time() - start_t:.3f} s.')
            
        else:
            print(f'{display_name} {checkpoint_path.split("/")[-1]} has no validation data, skipping...')
            
            
    print(f'Loaded {display_name} agent epochs log in {time.time() - start_t:.3f} s')
print(f'\nAll agent logs loaded.')

df = pd.DataFrame(validation_dict)
display(df)
# Out:
# Loading logs for il_10 agent from /data/ltf/code/retro_branching_offline/outputs/scratch_models/il_10/gnn/gnn_0/...
# Number of epochs: 100 | Number of checkpoints: 101 | Checkpoint frequency: 1
# il_10 checkpoint_1 has validator data, loading...
# Loaded validator data in 0.019 s.
# il_10 checkpoint_2 has validator data, loading...
# Loaded validator data in 0.020 s.
# il_10 checkpoint_3 has validator data, loading...
# Loaded validator data in 0.007 s.
# il_10 checkpoint_4 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10 checkpoint_5 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10 checkpoint_6 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10 checkpoint_7 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10 checkpoint_8 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10 checkpoint_9 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10 checkpoint_10 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_11 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10 checkpoint_12 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_13 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_14 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_15 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_16 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_17 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_18 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_19 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_20 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_21 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_22 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_23 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_24 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_25 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_26 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_27 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_28 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_29 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_30 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_31 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_32 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_33 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_34 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_35 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_36 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_37 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_38 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_39 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_40 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_41 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_42 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_43 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_44 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_45 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_46 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_47 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_48 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_49 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_50 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_51 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_52 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_53 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_54 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_55 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_56 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_57 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_58 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_59 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_60 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_61 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_62 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_63 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_64 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_65 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_66 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_67 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_68 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_69 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_70 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_71 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_72 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_73 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_74 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_75 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_76 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_77 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_78 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_79 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_80 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10 checkpoint_81 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_82 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_83 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10 checkpoint_84 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_85 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10 checkpoint_86 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_87 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_88 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_89 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_90 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10 checkpoint_91 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10 checkpoint_92 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10 checkpoint_93 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_94 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10 checkpoint_95 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_96 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10 checkpoint_97 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10 checkpoint_98 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_99 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10 checkpoint_100 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10 checkpoint_101 has validator data, loading...
# Loaded validator data in 0.003 s.
# Loaded il_10 agent epochs log in 0.003 s
#
# Loading logs for il_10_cl_10 agent from /data/ltf/code/retro_branching_offline/outputs/downsteam_models/il_10_cl_10/gnn/gnn_0/...
# Number of epochs: 100 | Number of checkpoints: 101 | Checkpoint frequency: 1
# il_10_cl_10 checkpoint_1 has validator data, loading...
# Loaded validator data in 0.009 s.
# il_10_cl_10 checkpoint_2 has validator data, loading...
# Loaded validator data in 0.006 s.
# il_10_cl_10 checkpoint_3 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_10 checkpoint_4 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_10 checkpoint_5 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_10 checkpoint_6 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_10 checkpoint_7 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_8 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_9 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_10 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_11 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_12 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_13 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_14 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_15 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_16 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_17 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_18 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_19 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_20 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_21 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_22 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_23 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_24 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_25 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_26 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_27 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_28 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_29 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_30 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_31 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_32 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_33 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_34 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_35 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_36 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_37 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_38 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_39 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_40 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_41 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_42 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_43 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_44 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_45 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_46 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_47 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_10 checkpoint_48 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_49 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_50 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_51 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_52 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_53 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_54 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_55 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_56 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_57 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_58 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_59 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_60 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_61 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_62 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_63 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_64 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_65 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_66 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_67 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_68 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_69 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_70 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_71 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_72 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_73 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_74 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_75 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_76 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_77 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_78 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_79 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_80 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_81 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_82 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_83 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_84 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_85 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10_cl_10 checkpoint_86 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_87 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_88 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_89 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_90 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_91 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_92 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_93 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_94 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_95 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_96 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_97 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_98 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_99 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_100 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_10 checkpoint_101 has validator data, loading...
# Loaded validator data in 0.004 s.
# Loaded il_10_cl_10 agent epochs log in 0.004 s
#
# Loading logs for il_10_cl_100 agent from /data/ltf/code/retro_branching_offline/outputs/downsteam_models/il_10_cl_100/gnn/gnn_0/...
# Number of epochs: 100 | Number of checkpoints: 101 | Checkpoint frequency: 1
# il_10_cl_100 checkpoint_1 has validator data, loading...
# Loaded validator data in 0.015 s.
# il_10_cl_100 checkpoint_2 has validator data, loading...
# Loaded validator data in 0.012 s.
# il_10_cl_100 checkpoint_3 has validator data, loading...
# Loaded validator data in 0.006 s.
# il_10_cl_100 checkpoint_4 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_5 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_6 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_7 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_8 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_9 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_10 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_11 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_12 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_13 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_14 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_15 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_16 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_17 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_18 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_19 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_20 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_21 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_22 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_23 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_24 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_25 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_26 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_27 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_28 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_29 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_30 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_31 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_32 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_33 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_34 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_35 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_36 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_37 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_38 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_39 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_40 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_41 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_42 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_43 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_44 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_45 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_46 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_47 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_48 has validator data, loading...
# Loaded validator data in 0.078 s.
# il_10_cl_100 checkpoint_49 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_50 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_51 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_52 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_53 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_54 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_55 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_56 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_57 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_58 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_59 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_60 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_61 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_62 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_63 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_64 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_65 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_66 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_67 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_68 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_69 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_70 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_71 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_72 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_73 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_74 has validator data, loading...
# Loaded validator data in 0.005 s.
# il_10_cl_100 checkpoint_75 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_76 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_77 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_78 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_79 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_80 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_81 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_82 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_83 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_84 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_85 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_86 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10_cl_100 checkpoint_87 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_88 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_89 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_90 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_91 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10_cl_100 checkpoint_92 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_93 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_94 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10_cl_100 checkpoint_95 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10_cl_100 checkpoint_96 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_97 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10_cl_100 checkpoint_98 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10_cl_100 checkpoint_99 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100 checkpoint_100 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10_cl_100 checkpoint_101 has validator data, loading...
# Loaded validator data in 0.003 s.
# Loaded il_10_cl_100 agent epochs log in 0.003 s
#
# Loading logs for il_10_cl_100_checkpoint2 agent from /data/ltf/code/retro_branching_offline/outputs/downsteam_models/il_10_cl_100_checkpoint2/gnn/gnn_0/...
# Number of epochs: 100 | Number of checkpoints: 101 | Checkpoint frequency: 1
# il_10_cl_100_checkpoint2 checkpoint_1 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_2 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_3 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_4 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_5 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_6 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_7 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_8 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_9 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_10 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_11 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_12 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_13 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_14 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_15 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_16 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_17 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_18 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_19 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_20 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_21 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_22 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_23 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_24 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_25 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_26 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_27 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_28 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_29 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_30 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_31 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_32 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_33 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_34 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_35 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_36 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_37 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_38 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_39 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_40 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_41 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_42 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_43 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_44 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_45 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_46 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_47 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_48 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_49 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_50 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_51 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_52 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_53 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_54 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_55 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_56 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_57 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_58 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_59 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_60 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_61 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_62 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_63 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_64 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_65 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_66 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_67 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_68 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_69 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_70 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_71 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_72 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_73 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_74 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_75 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_76 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_77 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_78 has no validation data, skipping...
# il_10_cl_100_checkpoint2 checkpoint_79 has validator data, loading...
# Loaded validator data in 0.003 s.
# il_10_cl_100_checkpoint2 checkpoint_80 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_81 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_82 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_83 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_84 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_85 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_86 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_87 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_88 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_89 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_90 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_91 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_92 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_93 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_94 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_95 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_96 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_97 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_98 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_99 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_100 has validator data, loading...
# Loaded validator data in 0.004 s.
# il_10_cl_100_checkpoint2 checkpoint_101 has validator data, loading...
# Loaded validator data in 0.004 s.
# Loaded il_10_cl_100_checkpoint2 agent epochs log in 0.004 s
#
# All agent logs loaded.
#        num_nodes  lp_iterations                     Agent  num_epochs  \
# 0           66.0         2919.0                     il_10           0
# 1           56.0         2757.0                     il_10           0
# 2           24.0          552.0                     il_10           0
# 3          235.0         9525.0                     il_10           0
# 4          262.0        10192.0                     il_10           0
# ...          ...            ...                       ...         ...
# 32586       40.0         1686.0  il_10_cl_100_checkpoint2         100
# 32587       10.0          397.0  il_10_cl_100_checkpoint2         100
# 32588       36.0         2504.0  il_10_cl_100_checkpoint2         100
# 32589      104.0         4389.0  il_10_cl_100_checkpoint2         100
# 32590       50.0         2250.0  il_10_cl_100_checkpoint2         100
#
#        Checkpoints
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 32586          101
# 32587          101
# 32588          101
# 32589          101
# 32590          101
#
# [32591 rows x 5 columns]

# %%
xaxis = 'num_epochs' # Epochs

rolling_window = None
# rolling_window = int(5)
# rolling_window = int(10)
# rolling_window = int(50)
# rolling_window = int(100)
# rolling_window = int(150)
# rolling_window = int(300)
# rolling_window = int(500) # paper training curve
# rolling_window = int(1e3)
# rolling_window = int(2e3)
# rolling_window = int(10e3)

xlog = False # False True
ylog = True # False True

xaxis_label_style = 'sci' # paper training curve
yaxis_label_style = 'plain'

xlim = None
# xlim = [0, 2e5] # paper training curve
# xlim = [0, 1.3e5]
# xlim = [0, 1.5e5]
# xlim = [0, 2e5]
# xlim = [0, 2.1e5]
# xlim = [0.15e5, None]
ylim = None

# legend = False # 'auto' False
legend = 'auto'
legend_font_size = 7.5 # same as default latex font#
# legend_font_size = 5 # smaller
# n_rows = 1
n_rows = 2

scaling_factor = 0.6 # paper training curve
# scaling_factor = 2.5
# scaling_factor = 0.4
width_scaling_factor = 1
height_scaling_factor = 1

aesthetics = PlotAesthetics()
aesthetics.set_icml_paper_plot_aesthetics() # paper training curve
# aesthetics.set_icml_paper_plot_aesthetics(font_scale=0.4, linewidth=0.4)

# %%
# calc rolling averages
_new_df = copy.deepcopy(df)
if rolling_window is not None:
    for param in ['num_nodes', 'lp_iterations']:
#         new_df[param] = _new_df[param].rolling(rolling_window, center=False).mean()
#         new_df[param] = _new_df[param].rolling(rolling_window, center=False).mean().fillna(method='bfill').fillna(method='ffill')
#         new_df[param] = _new_df[param].rolling(rolling_window, center=False).mean()
        new_df[param] = _new_df.groupby('Agent').rolling(rolling_window, center=False)[param].mean()
    print(f'\nNew DF after applying rolling average:')
    display(new_df[:15])
    display(new_df)
    display(new_df[-15:])
else:
    new_df = copy.deepcopy(df)

# xaxis = 'num_episodes' # TEMPORARY
if xaxis == 'num_epochs':
    xlabel = 'Epochs'
    
display(new_df)
# Out:
#        num_nodes  lp_iterations                     Agent  num_epochs  \
# 0           66.0         2919.0                     il_10           0
# 1           56.0         2757.0                     il_10           0
# 2           24.0          552.0                     il_10           0
# 3          235.0         9525.0                     il_10           0
# 4          262.0        10192.0                     il_10           0
# ...          ...            ...                       ...         ...
# 32586       40.0         1686.0  il_10_cl_100_checkpoint2         100
# 32587       10.0          397.0  il_10_cl_100_checkpoint2         100
# 32588       36.0         2504.0  il_10_cl_100_checkpoint2         100
# 32589      104.0         4389.0  il_10_cl_100_checkpoint2         100
# 32590       50.0         2250.0  il_10_cl_100_checkpoint2         100
#
#        Checkpoints
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 32586          101
# 32587          101
# 32588          101
# 32589          101
# 32590          101
#
# [32591 rows x 5 columns]

# %%
for metric in metrics:
    f, ax = plt.subplots(figsize=aesthetics.get_standard_fig_size(scaling_factor=scaling_factor, width_scaling_factor=width_scaling_factor, height_scaling_factor=height_scaling_factor))
    g = sns.lineplot(data=new_df, x=xaxis, y=metric, hue='Agent', linewidth=aesthetics.linewidth, legend=legend)
    if xlim is not None:
        plt.xlim(left=xlim[0], right=xlim[1])
    if ylim is not None:
        plt.ylim(bottom=ylim[0], top=ylim[1])
    # plt.legend(loc='upper right')
    # ax.legend(loc='lower left', bbox_to_anchor=(0, 1.02, 1, 0.2), ncol=2, prop={'size': 3})
    ax.legend(
#               loc='upper center',
#               loc='upper left',
              loc='best',
#               bbox_to_anchor=(0.5, 1.2), 
#               bbox_to_anchor=(0.5, 1.2),
              labelspacing=0.1,
              columnspacing=0.2,
              ncol=int(len(list(agent_to_path.keys()))/n_rows), 
              prop={'size': legend_font_size})
    g.set_xlabel(xlabel)
    g.set_ylabel(metric_to_label[metric])
    plt.ticklabel_format(style=xaxis_label_style, axis='x', scilimits=(0,0))
    plt.ticklabel_format(style=yaxis_label_style, axis='y', scilimits=(0,0))
    ax.tick_params(axis='both', which='major', pad=2)
    ax.xaxis.labelpad = 2
    ax.yaxis.labelpad = 2
    sns.despine(ax=ax) # remove top and right spines
    if xlog:
        g.set(xscale='log')
    if ylog:
        g.set(yscale='log')
    plt.gcf().patch.set_alpha(0.0)
    plt.show()
    
    
    # calc min-max vals and display in table with corresponding epoch and checkpoint
    summary_dict = defaultdict(list)
#     grouped_df = new_df.groupby(['Agent', 'num_epochs'])[metric].apply(list).to_dict()
    grouped_df = new_df.groupby(['Agent', 'num_epochs'])[metric].mean()
#     display(grouped_df)
    grouped_metric_df = grouped_df.groupby('Agent').apply(list).to_dict()
#     display(grouped_metric_df)
    
    grouped_df = new_df.groupby(['Agent', 'num_epochs'])['num_epochs'].mean()
#     display(grouped_df)
    grouped_epoch_df = grouped_df.groupby('Agent').apply(list).to_dict()
#     display(grouped_epoch_df)    
    
    grouped_df = new_df.groupby(['Agent', 'num_epochs'])['Checkpoints'].mean()
#     display(grouped_df)
    grouped_checkpoint_df = grouped_df.groupby('Agent').apply(list).to_dict()
#     display(grouped_checkpoint_df)
    
    for agent in agent_to_path:
        summary_dict['Agent'].append(agent)
        
        min_idx = np.argmin(grouped_metric_df[agent])
        min_val = grouped_metric_df[agent][min_idx]
        min_epoch = grouped_epoch_df[agent][min_idx]
        min_checkpoint = grouped_checkpoint_df[agent][min_idx]
        summary_dict[f'Min {metric} val'].append(min_val)
        summary_dict[f'Min {metric} epoch'].append(min_epoch)
        summary_dict[f'Min {metric} checkpoint'].append(min_checkpoint)
        
        max_idx = np.argmax(grouped_metric_df[agent])
        max_val = grouped_metric_df[agent][max_idx]
        max_epoch = grouped_epoch_df[agent][max_idx]
        max_checkpoint = grouped_checkpoint_df[agent][max_idx]
        summary_dict[f'Max {metric} val'].append(max_val)
        summary_dict[f'Max {metric} epoch'].append(max_epoch)
        summary_dict[f'Max {metric} checkpoint'].append(max_checkpoint)
        
        
    display(pd.DataFrame(summary_dict))
# Out:
#                       Agent  Min num_nodes val  Min num_nodes epoch  \
# 0                     il_10              48.51                 99.0
# 1               il_10_cl_10              50.88                 84.0
# 2              il_10_cl_100              49.12                 99.0
# 3  il_10_cl_100_checkpoint2              52.78                 88.0
#
#    Min num_nodes checkpoint  Max num_nodes val  Max num_nodes epoch  \
# 0                     100.0             363.67                  1.0
# 1                      85.0             174.48                  0.0
# 2                     100.0             322.02                  0.0
# 3                      89.0              57.75                 87.0
#
#    Max num_nodes checkpoint
# 0                       2.0
# 1                       1.0
# 2                       1.0
# 3                      88.0
#                       Agent  Min lp_iterations val  Min lp_iterations epoch  \
# 0                     il_10                2831.50                     89.0
# 1               il_10_cl_10                2946.50                     97.0
# 2              il_10_cl_100                2925.35                     99.0
# 3  il_10_cl_100_checkpoint2                3097.84                     88.0
#
#    Min lp_iterations checkpoint  Max lp_iterations val  \
# 0                          90.0               14453.73
# 1                          98.0                8036.06
# 2                         100.0               12539.98
# 3                          89.0                3300.91
#
#    Max lp_iterations epoch  Max lp_iterations checkpoint
# 0                      0.0                           1.0
# 1                      0.0                           1.0
# 2                      0.0                           1.0
# 3                     82.0                          83.0
